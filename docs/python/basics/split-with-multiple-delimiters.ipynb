# %% [raw]
# ---
# title: "Split With Multiple Delimiters"
# author: "Rj"
# date: 2019-05-20
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import re

# %%
content = "Hey, you - what are you doing here!?"

# %%
contents = re.findall(r"[\w']+", content)

# %%
contents
# Out:
# ['Hey', 'you', 'what', 'are', 'you', 'doing', 'here']

# %%
for c in contents:
    print(c)
# Out:
# Hey
# you
# what
# are
# you
# doing
# here
