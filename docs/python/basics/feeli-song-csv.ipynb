# %% [raw]
# ---
# title: "Feeli Song Collection"
# author: "Raja CSP Raman"
# date: 2019-04-20
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
from io import BytesIO
import requests
import pandas as pd

# %%
filename = 'https://docs.google.com/spreadsheet/ccc?key=1EfyD7A4YcdAzTfUO0t3yQ0HawetVF5pefS5pPyGVX4g&output=csv'

r = requests.get(filename)
data = r.content

# %%
df = pd.read_csv(BytesIO(data), index_col=0)

# %%
df.head()
# Out:
#                   Song Name Language  \
# S. NO
# 1.0      Classified - Inner  English
# 2.0    Avicii - Wake Me Up   English
# 3.0        Ziroq - Que Pena      NaN
# 4.0               Koko show  Finnish
# 5.0           Daniel Powter  English
#
#                                       YouTube link  Genre  Artist  \
# S. NO
# 1.0    https://www.youtube.com/watch?v=NGhyL8zg3_I    NaN     NaN
# 2.0    https://www.youtube.com/watch?v=IcrbM1l_BoI    NaN     NaN
# 3.0    https://www.youtube.com/watch?v=Ws_5XC1qqpo    NaN     NaN
# 4.0    https://www.youtube.com/watch?v=pmbWpPztg8Y    NaN     NaN
# 5.0    https://www.youtube.com/watch?v=gH476CxJxfg    NaN     NaN
#
#        Emotion Tag                                            Emotion Hint  \
# S. NO
# 1.0            NaN  Gives me some kind of confidence; Relaxed Cana...  NaN
# 2.0            NaN                                                NaN  NaN
# 3.0            NaN                                                NaN  NaN
# 4.0            NaN                                                NaN  NaN
# 5.0            NaN                                                NaN  NaN
#
#        Geo Location Lyrics Collector
# S. NO
# 1.0             NaN    NaN      Raja
# 2.0             NaN    NaN      Raja
# 3.0             NaN    NaN      Raja
# 4.0             NaN    NaN      Raja
# 5.0             NaN    NaN      Raja

# %%
df.tail()
# Out:
#                                            Song Name   Language  \
# S. NO
# 637.0                                       Chogada   Gujarathi
# 638.0                               The breakup song      Hindi
# 639.0                               Raat kamaal hai     Punjabi
# 640.0                                          Naah     Punjabi
# 641.0  Ever hit bollywood song mashup by Aksh baghla      Hindi
#
#                                       YouTube link  Genre  Artist  \
# S. NO
# 637.0                 https://youtu.be/BzcKINXf-rs    NaN     NaN
# 638.0  https://www.youtube.com/watch?v=kd5KqlmcHNo    NaN     NaN
# 639.0  https://www.youtube.com/watch?v=aNwWdF8qq-M    NaN     NaN
# 640.0  https://www.youtube.com/watch?v=8qs2dZO6wcc    NaN     NaN
# 641.0                 https://youtu.be/XvT0YoPDlCA    NaN     NaN
#
#        Emotion Tag                Emotion Hint  Geo Location Lyrics Collector
# S. NO
# 637.0          NaN          Let's garba !  NaN           NaN    NaN   Fatema
# 638.0          NaN  After breakup scene .  NaN           NaN    NaN   Fatema
# 639.0          NaN      It's party time !  NaN           NaN    NaN   Fatema
# 640.0          NaN          Savage life .  NaN           NaN    NaN   Fatema
# 641.0          NaN      Mashup mood ON !!  NaN           NaN    NaN   Fatema
