# %% [raw]
# ---
# title: "Two"
# author: "Raja CSP Raman"
# date: 2019-04-20
# description: "Two"
# type: technical_note
# draft: false
# ---

# %%
def add(a, b):
    return a + b

# %%
result = add(3, 5)

# %%
result
# Out:
# 8
