# %% [raw]
# ---
# title: "Empty"
# author: "Raja CSP Raman"
# date: 2019-04-20
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %% [markdown]
# #### Numpy Empty

# %%
a = np.empty([2, 2])

# %%
print(a)
# Out:
# [[1.28822975e-231 1.28822975e-231]
#  [1.29074295e-231 2.82475114e-309]]

# %%
b = np.empty([3, 1], dtype=np.int32)

# %%
print(b)
# Out:
# [[          0]
#  [  268435456]
#  [-1463385186]]

# %% [markdown]
# ##### Integer dtypes
#
# np.int8	 - Byte  - (-128 to 127)
#
# np.int16 - Integer - (-32768 to 32767)
#
# np.int32 - Integer - (-2147483648 to 2147483647)
#
# np.int64 - Integer  - (-9223372036854775808 to 9223372036854775807)
