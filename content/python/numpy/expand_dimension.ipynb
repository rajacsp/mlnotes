# %% [raw]
# ---
# title: "Expand Dimension"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
x = np.array([1, 2, 3, 4])

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
x.shape
# Out:
# (4,)

# %%
x = np.expand_dims(x, axis=0)

# %%
x
# Out:
# array([[1, 2, 3, 4]])

# %%
x.shape
# Out:
# (1, 4)

# %%
x = x.reshape(4, 1)

# %%
x
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
x.shape
# Out:
# (4, 1)
