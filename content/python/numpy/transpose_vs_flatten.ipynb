# %% [raw]
# ---
# title: "Transpose vs Flatten"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
a = np.array([5,4])[np.newaxis]

# %%
a
# Out:
# array([[5, 4]])

# %%
a.shape
# Out:
# (1, 2)

# %%
b = a.T

# %%
b
# Out:
# array([[5],
#        [4]])

# %%
c = np.array([
    [1, 2],
    [1, 4],
    [4, 5]
])

# %%
c
# Out:
# array([[1, 2],
#        [1, 4],
#        [4, 5]])

# %%
c.shape
# Out:
# (3, 2)

# %%
d = c.T

# %%
d
# Out:
# array([[1, 1, 4],
#        [2, 4, 5]])

# %%
e = c.flatten()

# %%
e
# Out:
# array([1, 2, 1, 4, 4, 5])

# %%
e.shape
# Out:
# (6,)

# %%
e.ndim
# Out:
# 1

# %%
c.ndim
# Out:
# 2
