# %% [raw]
# ---
# title: "VStack Simple"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
a = np.array([1, 2, 3])

# %%
b = np.array([19, 22, 33])

# %%
c = np.vstack((a, b))

# %%
c
# Out:
# array([[ 1,  2,  3],
#        [19, 22, 33]])

# %%
# It will stack row wise (vertically)

# %%
a.shape
# Out:
# (3,)

# %%
c.shape
# Out:
# (2, 3)

# %%
c.ndim
# Out:
# 2
