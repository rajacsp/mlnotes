# %% [raw]
# ---
# title: "One D Transpose"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
a = [3,6,9]

# %%
b = np.array(a)

# %%
b
# Out:
# array([3, 6, 9])

# %%
b.shape
# Out:
# (3,)

# %%
c = b.T

# %%
c
# Out:
# array([3, 6, 9])

# %%
c.shape
# Out:
# (3,)

# %%
# c didn't get the different shape because of the one D

# %%
e = np.array([a])

# %%
e
# Out:
# array([[3, 6, 9]])

# %%
e.shape
# Out:
# (1, 3)

# %%
f = e.T

# %%
f
# Out:
# array([[3],
#        [6],
#        [9]])

# %%
e.ndim
# Out:
# 2

# %% [markdown]
# more:
#     https://stackoverflow.com/questions/5954603/transposing-a-numpy-array
