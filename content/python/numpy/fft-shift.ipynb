# %% [raw]
# ---
# title: "FFT Shift"
# author: "Raja CSP Raman"
# date: 2019-04-20
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
N = 128
x = np.linspace(-5, 5, N)
y = np.exp(-x**2)

# %%
y_fft = np.fft.fftshift(np.fft.fft(y).real)
plt.plot(x, y_fft)

# %%
plt.show()
