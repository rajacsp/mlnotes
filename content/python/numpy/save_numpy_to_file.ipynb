# %% [raw]
# ---
# title: "Save Numpy to File"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
x = np.array([1, 2, 4, 5])

# %%
x
# Out:
# array([1, 2, 4, 5])

# %%
x.shape
# Out:
# (4,)

# %%
import tempfile

# %%
fp = tempfile.TemporaryFile()

# %%
x.tofile(fp)

# %%
# use the saved file

# %%
y = np.fromfile(fp)

# %%
y
# Out:
# array([], dtype=float64)

# %%
y.shape
# Out:
# (0,)

# %%
# Not sure what's happening. Need to double check again. (WIP)

# %% [markdown]
# More:
#
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.fromfile.html
