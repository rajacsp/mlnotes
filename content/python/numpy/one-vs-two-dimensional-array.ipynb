# %% [raw]
# ---
# title: "One vs Two Dimensional Array"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4])

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
a.shape
# Out:
# (4,)

# %%
b = np.array([
    [1], [2], [3], [4]
])

# %%
b
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
b.shape
# Out:
# (4, 1)

# %% [markdown]
# Diff between (4, ) and (4, 1)
#
# The difference between (4,) and (4,1) is that the first is the shape of a one-dimensional array, while the second is the shape of a 2-dimensional array whose 2nd dimension has length 1.
