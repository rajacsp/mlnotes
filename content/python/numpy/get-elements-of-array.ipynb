# %% [raw]
# ---
# title: "Get Elements of Array"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
abc = np.asarray([ 
 [[0.1, 0.2, 0.3], [0.5, 0.6, 0.7], [0.7, 0.8, 0.9]],
 [[0.3, 0.1, 0.4], [0.4, 0.5, 0.6], [0.5, 0.6, 0.1]]])

# %%
abc
# Out:
# array([[[0.1, 0.2, 0.3],
#         [0.5, 0.6, 0.7],
#         [0.7, 0.8, 0.9]],
#
#        [[0.3, 0.1, 0.4],
#         [0.4, 0.5, 0.6],
#         [0.5, 0.6, 0.1]]])

# %%
type(abc)
# Out:
# numpy.ndarray

# %%
abc.shape
# Out:
# (2, 3, 3)

# %%
result = [list(abc[:, i, j]) for i in range(3) for j in range(3)]

# %%
result
# Out:
# [[0.1, 0.3],
#  [0.2, 0.1],
#  [0.3, 0.4],
#  [0.5, 0.4],
#  [0.6, 0.5],
#  [0.7, 0.6],
#  [0.7, 0.5],
#  [0.8, 0.6],
#  [0.9, 0.1]]

# %%
type(result)
# Out:
# list
