# %% [raw]
# ---
# title: "Transpose Simple"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
x = np.arange(4).reshape((2,2))

# %%
x.shape
# Out:
# (2, 2)

# %%
x
# Out:
# array([[0, 1],
#        [2, 3]])

# %%
y = np.transpose(x)

# %%
y
# Out:
# array([[0, 2],
#        [1, 3]])
