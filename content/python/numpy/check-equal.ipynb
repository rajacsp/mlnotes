# %% [raw]
# ---
# title: "Check Equal"
# author: "Raja CSP Raman"
# date: 2019-04-22
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
a = np.random.randint(1, 10, 5)

# %%
print(a)
# Out:
# [2 5 7 5 7]

# %%
b = np.random.randint(1, 10, 5)

# %%
print(b)
# Out:
# [7 1 1 6 6]

# %%
# All close
flag = np.allclose(a, b)

# %%
flag
# Out:
# False

# %%
c = np.random.random(5)

# %%
print(c)
# Out:
# [0.0780987  0.87270989 0.36496802 0.44654423 0.30848166]

# %%
d = np.random.random(5)

# %%
print(d)
# Out:
# [0.45278705 0.26708296 0.34121466 0.15848768 0.62194573]

# %%
flag2 = np.allclose(c, d)

# %%
flag2
# Out:
# False

# %%
e = np.array([1, 3, 5])
f = np.array([1, 3, 5])

# %%
g = np.allclose(e, f)

# %%
g
# Out:
# True
