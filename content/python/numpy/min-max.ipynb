# %% [raw]
# ---
# title: "Min Max"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
a = np.array([
    [1, 2],
    [3, 4]
])

# %%
a.min()
# Out:
# 1

# %%
a.min(axis=0)
# Out:
# array([1, 2])

# %%
a.min(axis=1)
# Out:
# array([1, 3])

# %%
np.min(a)
# Out:
# 1

# %%
np.min(a, axis=0)
# Out:
# array([1, 2])

# %%
a.max()
# Out:
# 4

# %%
a.max(axis=0)
# Out:
# array([3, 4])

# %%
a.max(axis=1)
# Out:
# array([2, 4])
