# %% [raw]
# ---
# title: "Zeros"
# author: "Raja CSP Raman"
# date: 2019-04-20
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %% [markdown]
# #### Numpy Zeros

# %%
a = np.zeros(5)

# %%
print(a)
# Out:
# [0. 0. 0. 0. 0.]

# %%
a.shape
# Out:
# (5,)

# %% [markdown]
# ##### Numpy Zeros with int data type

# %%
b = np.zeros(5, dtype=np.int)

# %%
print(b)
# Out:
# [0 0 0 0 0]

# %% [markdown]
# ##### Integer dtypes
#
# np.int8	 - Byte  - (-128 to 127)
#
# np.int16 - Integer - (-32768 to 32767)
#
# np.int32 - Integer - (-2147483648 to 2147483647)
#
# np.int64 - Integer  - (-9223372036854775808 to 9223372036854775807)
