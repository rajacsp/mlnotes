# %% [raw]
# ---
# title: "Sorting"
# author: "Raja CSP Raman"
# date: 2019-04-20
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
a = np.random.random(5)

# %%
print(a)
# Out:
# [0.56819836 0.0468077  0.1572067  0.67552432 0.5527355 ]

# %%
a.sort()

# %%
print(a)
# Out:
# [0.0468077  0.1572067  0.5527355  0.56819836 0.67552432]
