# %% [raw]
# ---
# title: "Ones"
# author: "Raja CSP Raman"
# date: 2019-04-20
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %% [markdown]
# #### Numpy Ones

# %%
a = np.ones(5)

# %%
print(a)
# Out:
# [1. 1. 1. 1. 1.]

# %%
b = np.ones([2, 2], dtype=np.float16)

# %%
print(b)
# Out:
# [[1. 1.]
#  [1. 1.]]
