# %% [raw]
# ---
# title: "Einsum Basics"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4])

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
b = np.array([5, 6, 7, 8])

# %%
b
# Out:
# array([5, 6, 7, 8])

# %%
# Sum of array a
np.einsum('i->', a)
# Out:
# 10

# %% [markdown]
# More
#
# http://ajcr.net/Basic-guide-to-einsum/
#
# https://stackoverflow.com/questions/26089893/understanding-numpys-einsum
#
# http://numpy-discussion.10968.n7.nabble.com/einsum-td11810.html
