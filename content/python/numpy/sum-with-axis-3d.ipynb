# %% [raw]
# ---
# title: "Sum with Axis 3D"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
x = np.array([
    [
        [1,2],
        [3,4]
    ],
    [
        [1,2],
        [3,4]
    ]
])

# %%
x
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[1, 2],
#         [3, 4]]])

# %%
x.ndim
# Out:
# 3

# %%
x[0]
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
x[0][0]
# Out:
# array([1, 2])

# %%
x[0][0][0]
# Out:
# 1

# %%
x.sum(axis=0)
# Out:
# array([[2, 4],
#        [6, 8]])

# %% [markdown]
# More
#
# https://medium.com/@aerinykim/numpy-sum-axis-intuition-6eb94926a5d1
