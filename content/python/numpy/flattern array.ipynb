# %% [raw]
# ---
# title: "Flatten Array"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
a = np.array([
    [
        [1, 2],
        [3, 4]
    ],
    [
        [5, 6],
        [7, 8]
    ],
])

# %%
a
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
a.ndim
# Out:
# 3

# %%
a.shape
# Out:
# (2, 2, 2)

# %%
b = a.flatten()

# %%
b
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
b.ndim
# Out:
# 1

# %%
b.shape
# Out:
# (8,)
