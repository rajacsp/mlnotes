# %% [raw]
# ---
# title: "Bincount"
# author: "Raja CSP Raman"
# date: 2019-05-07
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
a = np.array([1, 2, 4, 5])

# %%
b = np.bincount(a)

# %%
b
# Out:
# array([0, 1, 1, 0, 1, 1])

# %%
b.size
# Out:
# 6
