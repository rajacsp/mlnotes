# %% [raw]
# ---
# title: "Numpy Shape"
# author: "Raja CSP Raman"
# date: 2019-04-20
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
a = np.array([1, 2, 4, 5])

# %%
print(a)
# Out:
# [1 2 4 5]

# %%
a
# Out:
# array([1, 2, 4, 5])

# %%
a.shape
# Out:
# (4,)

# %%
# change the shape

a.shape = (2, 2)

# %%
a
# Out:
# array([[1, 2],
#        [4, 5]])

# %%
print(a)
# Out:
# [[1 2]
#  [4 5]]

# %%
b = np.array([[1, 3, 5, 2, 4], [8, 6, 9, 7, 10]])

# %%
print(b)
# Out:
# [[ 1  3  5  2  4]
#  [ 8  6  9  7 10]]

# %%
b.shape
# Out:
# (2, 5)

# %%
b.shape = (5, 2)

# %%
print(b)
# Out:
# [[ 1  3]
#  [ 5  2]
#  [ 4  8]
#  [ 6  9]
#  [ 7 10]]

# %%
b.shape = (10, 1)

# %%
print(b)
# Out:
# [[ 1]
#  [ 3]
#  [ 5]
#  [ 2]
#  [ 4]
#  [ 8]
#  [ 6]
#  [ 9]
#  [ 7]
#  [10]]

# %%
# get the numebr of array dimension
print(b.ndim)
# Out:
# 2
