# %% [raw]
# ---
# title: "Min Max Mean"
# author: "Raja CSP Raman"
# date: 2019-04-20
# description: "-"
# type: technical_note
# draft: false
# ---

# %%
import numpy as np

# %%
java_questions = np.array([201, 20, 292, 15, 299, 28])

# %%
java_questions
# Out:
# array([201,  20, 292,  15, 299,  28])

# %% [markdown]
# #### Min

# %%
java_questions.min()
# Out:
# 15

# %% [markdown]
# #### Max

# %%
java_questions.max()
# Out:
# 299

# %% [markdown]
# #### Mean

# %%
java_questions.mean()
# Out:
# 142.5

# %% [markdown]
# #### Sum

# %%
java_questions.sum()
# Out:
# 855
