# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5, 6, 7]

# %%
y = [
    0,
    220,
    380,
    500,
    540,
    540,
    590,
]

# %%
y
# Out:
# [0, 220, 380, 500, 540, 540, 590]

# %%
plt.plot(x, y, 'ro')

# plt.axis([0, 10, 20, 100])
