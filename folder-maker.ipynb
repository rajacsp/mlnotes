# %%
import os

# %%
files = os.listdir('content/')
for name in files:
    #print(name)
    
    # find one step folder
    subfiles = os.listdir('content/'+name)
    
    for subfilename in subfiles:
        
        # ignore ipynb_checkpoints
        if(subfilename.startswith(".") or subfilename.startswith("_")):
            continue
        
        print(subfilename)
# Out:
# basics
# yellowbrick
# plot
# image-analysis
# audio_analysis
# geopandas
# resources
# regex
# numpy
# statsmodel
# sklearn
# numba-work
# gensim-samples
# file-utils
# tips
# text-processing
# tensorflow-work
# sentiment
# webreader
# scipy
# pandas
# hbr
# resources
# psychology
